# %%
import subprocess, os

os.makedirs('output', exist_ok=True)

result = subprocess.run(['nvidia-smi'], capture_output=True, text=True)
print(result.stdout)

with open('output/gpu_info.txt', 'w') as f:
    f.write(result.stdout)

print('Done!')
